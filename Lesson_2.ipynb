# %% [markdown]
# # Data structures

# %% [markdown]
# ![structaures.png](attachment:structaures.png)

# %% [markdown]
# ## List
# ## Tuple
# ## Dictionary
# ## Set

# %% [markdown]
# # What Is a List?
# A list is a collection of items in a particular order. You can make a list that
# includes the letters of the alphabet, the digits from 0–9, or the names of
# all the people in your family. You can put anything you want into a list, andthe items in your list don’t have to be related in any particular way.

# %%
langueges = ['C', 'c++', 'python', 'java']

# %%
print(langueges[0])
# Out:
# C

# %%
print(langueges[2])
# Out:
# python

# %%
print(langueges[-1])
# Out:
# java

# %%
print(langueges[-2].title())
# Out:
# Python

# %% [markdown]
# # !Index Positions Start at 0, Not 1!

# %%
names = ['ali', 'reza', 'sara', 'alireza']

# %%
message = f" My name is {names[-1].title()}"

# %%
print(message)
# Out:
#  My name is Alireza

# %% [markdown]
# # Changing, Adding, and Removing Elements

# %%
numbers = ['zero', 'one', 'two', 'three']

# %%
print(numbers[0])
# Out:
# zero

# %%
numbers[0] = 'null'

# %%
print(numbers[0])
# Out:
# null

# %%
print(numbers)
# Out:
# ['null', 'one', 'two', 'three']

# %%
numbers.append('four')

# %%
print(numbers)
# Out:
# ['null', 'one', 'two', 'three', 'four']

# %%
numbers.insert(0, 'zero')

# %%
print(numbers)
# Out:
# ['zero', 'null', 'one', 'two', 'three', 'four']

# %%
del numbers[1]

# %%
print(numbers)
# Out:
# ['zero', 'one', 'two', 'three', 'four']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
popped_motorcycle = motorcycles.pop()
print(motorcycles)
print(popped_motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha']
# suzuki

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
last_owned = motorcycles.pop()
print(f"The last motorcycle I owned was a {last_owned.title()}.")
# Out:
# The last motorcycle I owned was a Suzuki.

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.title()}.")
# Out:
# The first motorcycle I owned was a Honda.

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %% [markdown]
# # Organizing a List

# %% [markdown]
# Sorting a List Permanently with the sort() Method

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort(reverse=True)
print(cars)
# Out:
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
print("Here is the original list:")
print(cars)
print("\nHere is the sorted list:")
print(sorted(cars))
print("\nHere is the original list again:")
print(cars)
# Out:
# Here is the original list:
# ['bmw', 'audi', 'toyota', 'subaru']
#
# Here is the sorted list:
# ['audi', 'bmw', 'subaru', 'toyota']
#
# Here is the original list again:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
print(cars)
cars.reverse()
print(cars)
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']
# ['subaru', 'toyota', 'audi', 'bmw']

# %%
len(cars)
# Out:
# 4

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_280432/3878205628.py in <module>
#       1 motorcycles = ['honda', 'yamaha', 'suzuki']
# ----> 2 print(motorcycles[3])
#
# IndexError: list index out of range

# %%
motorcycles = []
print(motorcycles[-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_280432/3288811120.py in <module>
#       1 motorcycles = []
# ----> 2 print(motorcycles[-1])
#
# IndexError: list index out of range

# %%
cars
# Out:
# ['subaru', 'toyota', 'audi', 'bmw']

# %%
cars.index('bmw')
# Out:
# 3

# %%
family = ['sister', 'brother', 'mother', 'father']

# %%
for member in family:
    print(member)
# Out:
# sister
# brother
# mother
# father

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")
    print(f"I can't wait to see your next trick, {magician.title()}.\n")
print("Thank you, everyone. That was a great magic show!")
# Out:
# Alice, that was a great trick!
# I can't wait to see your next trick, Alice.
#
# David, that was a great trick!
# I can't wait to see your next trick, David.
#
# Carolina, that was a great trick!
# I can't wait to see your next trick, Carolina.
#
# Thank you, everyone. That was a great magic show!

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
print(magician)
# Out:
#   File "/tmp/ipykernel_280432/2510761304.py", line 3
#     print(magician)
#     ^
# IndentationError: expected an indented block

# %%
message = "Hello Python world!"
  print(message)
# Out:
#   File "/tmp/ipykernel_280432/3607441400.py", line 2
#     print(message)
#     ^
# IndentationError: unexpected indent

# %%
message = "Hello Python world!"
print(message)
# Out:
# Hello Python world!

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians
    print(magician)
# Out:
#   File "/tmp/ipykernel_280432/518316207.py", line 2
#     for magician in magicians
#                              ^
# SyntaxError: invalid syntax

# %%
for value in range(1, 5):
    print(value)
# Out:
# 1
# 2
# 3
# 4

# %%
for value in range(1, 6):
    print(value)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers = list(range(1, 6))
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
even_numbers = list(range(2, 11, 2))
print(even_numbers)
# Out:
# [2, 4, 6, 8, 10]

# %%
squares = []
for value in range(1, 11):

    square = value ** 2

    squares.append(square)
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
digits = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
min(digits)
# Out:
# 0

# %%
max(digits)
# Out:
# 9

# %%
sum(digits)
# Out:
# 45

# %%
squares = [value**2 for value in range(1, 11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
players = ['hasan', 'sara', 'reza', 'mohamad']

# %%
print(players[0:3])
# Out:
# ['hasan', 'sara', 'reza']

# %%
print(players[1:-1])
# Out:
# ['sara', 'reza']

# %%
print(players[:3])
# Out:
# ['hasan', 'sara', 'reza']

# %%
print(players[2:])
# Out:
# ['reza', 'mohamad']

# %%
print(players[-3:])
# Out:
# ['sara', 'reza', 'mohamad']

# %%
print("Here are the first three players on my team:")
for player in players[:3]:
    print(player.title())
# Out:
# Here are the first three players on my team:
# Hasan
# Sara
# Reza

# %%
my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods[:2]
print("My favorite foods are:")
print(my_foods)
print("\nMy friend's favorite foods are:")
print(friend_foods)
# Out:
# My favorite foods are:
# ['pizza', 'falafel', 'carrot cake']
#
# My friend's favorite foods are:
# ['pizza', 'falafel']

# %%
dimensions = (200, 50)
print(dimensions[0])
print(dimensions[1])
# Out:
# 200
# 50

# %%
dimensions[0] = 250
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_280432/106102430.py in <module>
# ----> 1 dimensions[0] = 250
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_t = (3)

# %%
my_t[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_280432/160601778.py in <module>
# ----> 1 my_t[0]
#
# TypeError: 'int' object is not subscriptable

# %%
my_t = (3,)

# %%
my_t[0]
# Out:
# 3

# %%
dimensions = (200, 50)
for dimension in dimensions:
    print(dimension)
# Out:
# 200
# 50

# %%
dimensions = (200, 50)
print("Original dimensions:")
for dimension in dimensions:
    print(dimension)
# Out:
# Original dimensions:
# 200
# 50

# %%
dimensions = (400, 100)
print("\nModified dimensions:")
for dimension in dimensions:
    print(dimension)
# Out:
# Modified dimensions:
# 400
# 100

# %%
dimensions
# Out:
# (400, 100)

# %% [markdown]
# 79-character standard line length
